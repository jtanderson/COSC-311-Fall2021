# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %%
adults = pd.read_csv('data/adult.data', header=None, skipinitialspace=True,
    names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
            'marital-status', 'occupation', 'relationship', 'race', 'sex',
            'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
)

# %%
adults.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
adults[:1]['education'] == 'Bachelors'
# Out:
# 0    True
# Name: education, dtype: bool

# %%
adults[:1]['age'] == 39
# Out:
# 0    True
# Name: age, dtype: bool

# %%
adults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# histogram the ages of these adults?
# to ask what does the distribution of ages look like?
adults['age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
# compare the ages of the two income classes
adults['age'][adults['income'] == '<=50K'].hist(bins=20)
adults['age'][adults['income'] == '>50K'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
adults['education-num'][adults['income'] == '<=50K'].hist(bins=20)
adults['education-num'][adults['income'] == '>50K'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
adults.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adults[['education-num', 'education']][(adults['education'] == 'HS-grad') & (adults['education-num'] != 9)]
# Out:
# Empty DataFrame
# Columns: [education-num, education]
# Index: []

# %%
adults['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
males = adults[adults['sex'] == 'Male']
females = adults[adults['sex'] == 'Female']

# %%
males['age'].hist(bins=20, legend=True)
females['age'].hist(bins=20, legend=True)
# Out:
# <AxesSubplot:>

# %%
males[males['income'] == '>50K']['age'].hist(bins=20, legend=True)
females[females['income'] == '>50K']['age'].hist(bins=20, legend=True)
# Out:
# <AxesSubplot:>

# %%
males[males['income'] == '<=50K']['age'].hist(bins=20, legend=True)
females[females['income'] == '<=50K']['age'].hist(bins=20, legend=True)
plt.legend(['males', 'females'])

# %%
males['age'].hist(bins=20, legend=True).axis
# Out:
# <bound method _AxesBase.axis of <AxesSubplot:>>

# %% [markdown]
# # Building nice graphs

# %%
# Example:

# %%
adults['education'].unique() # extract the unique values into an array
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
# x-axis will be the level of education
#xs = adults['education'].unique()
#print(xs)
# y-axis will be the max age among adults with that level of education

# v1 use a regular for-loop with appending
#ys = []
#for education_level in xs:
#    ys += [adults[adults['education'] == education_level]['age'].max()]

# v2 use list comp
#ys = [adults[adults['education'] == education_level]['age'].max() for education_level in xs]
 
# v3 use pandas built-in aggregates
ys = adults.groupby('education')[['education-num','hours-per-week']].mean().sort_values('education-num')['hours-per-week']
#print(ys)

#for level in ys.keys():
#    print(f'ys[{level}] is {ys[level]}')

plt.barh(ys.keys(), ys)
plt.title('More education means more work, on average')
plt.xlabel('Average hours worked per week')
plt.ylabel('Highest level of education')
plt.vlines([i for i in range(5,50,5)], ymin=0, ymax=17, colors='white')

# %%
# gets the max of the series of ages for all adults having a B.S. level education
adults[adults['education'] == 'Preschool']['age'].min()
# Out:
# 19

# %%
ys = adults.groupby('education')['age'].describe()
ys
# Out:
#                 count       mean        std   min    25%   50%   75%   max
# education
# 10th            933.0  37.429796  16.720713  17.0  22.00  34.0  52.0  90.0
# 11th           1175.0  32.355745  15.545485  17.0  18.00  28.0  43.0  90.0
# 12th            433.0  32.000000  14.334625  17.0  19.00  28.0  41.0  79.0
# 1st-4th         168.0  46.142857  15.615625  19.0  33.00  46.0  57.0  90.0
# 5th-6th         333.0  42.885886  15.557285  17.0  29.00  42.0  54.0  84.0
# 7th-8th         646.0  48.445820  16.092350  17.0  34.25  50.0  61.0  90.0
# 9th             514.0  41.060311  15.946862  17.0  28.00  39.0  54.0  90.0
# Assoc-acdm     1067.0  37.381443  11.095177  19.0  29.00  36.0  44.0  90.0
# Assoc-voc      1382.0  38.553546  11.631300  19.0  30.00  37.0  46.0  84.0
# Bachelors      5355.0  38.904949  11.912210  19.0  29.00  37.0  46.0  90.0
# Doctorate       413.0  47.702179  11.784716  24.0  39.00  47.0  55.0  80.0
# HS-grad       10501.0  38.974479  13.541524  17.0  28.00  37.0  48.0  90.0
# Masters        1723.0  44.049913  11.068935  18.0  36.00  43.0  51.0  90.0
# Preschool        51.0  42.764706  15.126914  19.0  31.00  41.0  53.5  75.0
# Prof-school     576.0  44.746528  11.962477  25.0  36.00  43.0  51.0  90.0
# Some-college   7291.0  35.756275  13.474051  17.0  24.00  34.0  45.0  90.0

# %%
some = adults.head()

# %%
some
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
some.sort_values('education-num')
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 3   53           Private  234721       11th              7
# 2   38           Private  215646    HS-grad              9
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 3             0             0              40  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
some.groupby('education')[['education-num','age']].max().sort_values('education-num')
# Out:
#            education-num  age
# education
# 11th                   7   53
# HS-grad                9   38
# Bachelors             13   50

# %%
ys
# Out:
#                 count       mean        std   min    25%   50%   75%   max
# education
# 10th            933.0  37.429796  16.720713  17.0  22.00  34.0  52.0  90.0
# 11th           1175.0  32.355745  15.545485  17.0  18.00  28.0  43.0  90.0
# 12th            433.0  32.000000  14.334625  17.0  19.00  28.0  41.0  79.0
# 1st-4th         168.0  46.142857  15.615625  19.0  33.00  46.0  57.0  90.0
# 5th-6th         333.0  42.885886  15.557285  17.0  29.00  42.0  54.0  84.0
# 7th-8th         646.0  48.445820  16.092350  17.0  34.25  50.0  61.0  90.0
# 9th             514.0  41.060311  15.946862  17.0  28.00  39.0  54.0  90.0
# Assoc-acdm     1067.0  37.381443  11.095177  19.0  29.00  36.0  44.0  90.0
# Assoc-voc      1382.0  38.553546  11.631300  19.0  30.00  37.0  46.0  84.0
# Bachelors      5355.0  38.904949  11.912210  19.0  29.00  37.0  46.0  90.0
# Doctorate       413.0  47.702179  11.784716  24.0  39.00  47.0  55.0  80.0
# HS-grad       10501.0  38.974479  13.541524  17.0  28.00  37.0  48.0  90.0
# Masters        1723.0  44.049913  11.068935  18.0  36.00  43.0  51.0  90.0
# Preschool        51.0  42.764706  15.126914  19.0  31.00  41.0  53.5  75.0
# Prof-school     576.0  44.746528  11.962477  25.0  36.00  43.0  51.0  90.0
# Some-college   7291.0  35.756275  13.474051  17.0  24.00  34.0  45.0  90.0

# %%
ys = adults.groupby('education')[['education-num','hours-per-week']].mean().sort_values('education-num')['hours-per-week']

print(ys)
# Out:
# education
# Preschool       36.647059
# 1st-4th         38.255952
# 5th-6th         38.897898
# 7th-8th         39.366873
# 9th             38.044747
# 10th            37.052519
# 11th            33.925957
# 12th            35.780600
# HS-grad         40.575374
# Some-college    38.852284
# Assoc-voc       41.610709
# Assoc-acdm      40.504217
# Bachelors       42.614006
# Masters         43.836332
# Prof-school     47.425347
# Doctorate       46.973366
# Name: hours-per-week, dtype: float64

# %%
# need to import seaboarn for this
# may need to pip install seaborn first

sb.set_theme(font_scale=1.2, font='Times')
# sb.color_palette("husl", 9)

ax = sb.barplot(x=ys, y=ys.keys(), orient="h", palette='flare')

ax.set(xlabel='Average hours worked per week')
ax.set(ylabel='Education Level')
ax.set(title='Higher Education means higher average work hours')
# Out:
# [Text(0.5, 1.0, 'Higher Education means higher average work hours')]

# %%
adults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adults[['age', 'capital-gain', 'capital-loss']].describe()
# Out:
#                 age  capital-gain  capital-loss
# count  32561.000000  32561.000000  32561.000000
# mean      38.581647   1077.648844     87.303830
# std       13.640433   7385.292085    402.960219
# min       17.000000      0.000000      0.000000
# 25%       28.000000      0.000000      0.000000
# 50%       37.000000      0.000000      0.000000
# 75%       48.000000      0.000000      0.000000
# max       90.000000  99999.000000   4356.000000

# %%
adults['race'].unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
len(adults['native-country'].unique())
# Out:
# 42

# %%
adults['native-country'].unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
# look at proportion of more or less than 50k/year by native country

native_country_wealthy = adults[['native-country', 'income']].groupby(['native-country', 'income']) # [adults['income'] == '>50K'].count()
native_country_wealthy

# %%
len(native_country_wealthy)
#len(native_country_poor)
#len(adults[['native-country', 'income']].groupby('native-country').count())
# Out:
# 82

# %%
"""{
    'wealthy': native_country_wealthy.values[:,0],
    'poor': native_country_wealthy.values[:,0],
    'total': adults[['native-country', 'income']].groupby('native-country').count().values[:,0]
}"""
# Out:
# "{\n    'wealthy': native_country_wealthy.values[:,0],\n    'poor': native_country_wealthy.values[:,0],\n    'total': adults[['native-country', 'income']].groupby('native-country').count().values[:,0]\n}"

# %%
#incomes = pd.DataFrame({
#    'wealthy': native_country_wealthy.values[:,0],
##    'poor': native_country_wealthy.values[:,0],
#    'total': adults[['native-country', 'income']].groupby('native-country').count().values[:,0]
#}, columns=['wealthy', 'poor', 'total'])
#incomes['wealthy'] = native_country_wealthy
#incomes['poor'] = native_country_wealthy
#incomes['total'] = adults[['native-country', 'income']].groupby('native-country').count()

# %%
#incomes['wealthy'] =  incomes['wealthy'] / incomes['total']
#incomes['poor'] =  incomes['poor'] / incomes['total']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14995/3723639777.py in <module>
# ----> 1 incomes['wealthy'] =  incomes['wealthy'] / incomes['total']
#       2 incomes['poor'] =  incomes['poor'] / incomes['total']
#
# NameError: name 'incomes' is not defined

# %%
#incomes

# %%
#(1-incomes[['wealthy','poor']].sort_values('wealthy', ascending=False)['wealthy'])

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# ### Heading 3
#
# - list item 1
# - list item 2

# %%
ax = incomes[['wealthy','poor']].sort_values('wealthy', ascending=True).plot.barh(figsize=(25,45), stacked=True, grid=False, legend=False, fontsize=16)
plt.xticks([])
ax.vlines(x=incomes[['wealthy','poor']].max()['wealthy'], ymin=-0.25, ymax=39.23, color='gray')
ax.bar_label(ax.containers[0], color='white', fontsize=16, fmt='%2.2f', padding=-35)
ax.bar_label(ax.containers[0], 
             labels=np.round((1-incomes[['wealthy','poor']].sort_values('wealthy', ascending=True)['wealthy']),2), 
             color='white', fontsize=16, fmt='%2.2f', padding=5)
ax.set_facecolor('white')
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14995/3334940322.py in <module>
# ----> 1 ax = incomes[['wealthy','poor']].sort_values('wealthy', ascending=True).plot.barh(figsize=(25,45), stacked=True, grid=False, legend=False, fontsize=16)
#       2 plt.xticks([])
#       3 ax.vlines(x=incomes[['wealthy','poor']].max()['wealthy'], ymin=-0.25, ymax=39.23, color='gray')
#       4 ax.bar_label(ax.containers[0], color='white', fontsize=16, fmt='%2.2f', padding=-35)
#       5 ax.bar_label(ax.containers[0],
#
# NameError: name 'incomes' is not defined

# %%
incomes[['wealthy','poor']].max()['wealthy']

# %%
all_adults = adults[['age', 'fnlwgt']].groupby('age').mean()
males = adults[adults['sex'] == 'Male'][['age', 'fnlwgt']].groupby('age').mean()
females = adults[adults['sex'] == 'Female'][['age', 'fnlwgt']].groupby('age').mean()

plt.plot(all_adults.index, all_adults['fnlwgt'])
plt.plot(males.index, males['fnlwgt'])
plt.plot(females.index, females['fnlwgt'])

#all_adults.index

# %%
tmp = adults[['age', 'income', 'sex']][(adults['income'] == '>50K') & (adults['sex'] == 'Female')]
#tmp.loc[1]
tmp.reset_index()

# %%
len(adults['sex'] == 'Female')

# %%
adults.loc[1] # gets the row with index

# %%
adults[1:2] # slice

# %%
adults

# %%
(adults[['occupation', 'sex','hours-per-week']]
    .groupby(['occupation', 'sex'])
    .mean()
    .reset_index())

# %%
(adults[['occupation', 'sex','hours-per-week']]
    .groupby(['occupation', 'sex'])
    .mean()
    .reset_index()
    .pivot(index='occupation', columns='sex', values='hours-per-week')).plot.bar()

# %%
educations = adults['education'].unique()
education_nums = adults['education-num'].unique()

def level_given_num(a,b):
    return f'P({a}|{b})'

table = np.array(
    [ [level_given_num(b,a) for a in education_nums] for b in educations ]
)

pd.DataFrame(table, columns=education_nums, index=educations)
# Out:
#                               13                 9                  7   \
# Bachelors        P(Bachelors|13)     P(Bachelors|9)     P(Bachelors|7)
# HS-grad            P(HS-grad|13)       P(HS-grad|9)       P(HS-grad|7)
# 11th                  P(11th|13)          P(11th|9)          P(11th|7)
# Masters            P(Masters|13)       P(Masters|9)       P(Masters|7)
# 9th                    P(9th|13)           P(9th|9)           P(9th|7)
# Some-college  P(Some-college|13)  P(Some-college|9)  P(Some-college|7)
# Assoc-acdm      P(Assoc-acdm|13)    P(Assoc-acdm|9)    P(Assoc-acdm|7)
# Assoc-voc        P(Assoc-voc|13)     P(Assoc-voc|9)     P(Assoc-voc|7)
# 7th-8th            P(7th-8th|13)       P(7th-8th|9)       P(7th-8th|7)
# Doctorate        P(Doctorate|13)     P(Doctorate|9)     P(Doctorate|7)
# Prof-school    P(Prof-school|13)   P(Prof-school|9)   P(Prof-school|7)
# 5th-6th            P(5th-6th|13)       P(5th-6th|9)       P(5th-6th|7)
# 10th                  P(10th|13)          P(10th|9)          P(10th|7)
# 1st-4th            P(1st-4th|13)       P(1st-4th|9)       P(1st-4th|7)
# Preschool        P(Preschool|13)     P(Preschool|9)     P(Preschool|7)
# 12th                  P(12th|13)          P(12th|9)          P(12th|7)
#
#                               14                 5                   10  \
# Bachelors        P(Bachelors|14)     P(Bachelors|5)     P(Bachelors|10)
# HS-grad            P(HS-grad|14)       P(HS-grad|5)       P(HS-grad|10)
# 11th                  P(11th|14)          P(11th|5)          P(11th|10)
# Masters            P(Masters|14)       P(Masters|5)       P(Masters|10)
# 9th                    P(9th|14)           P(9th|5)           P(9th|10)
# Some-college  P(Some-college|14)  P(Some-college|5)  P(Some-college|10)
# Assoc-acdm      P(Assoc-acdm|14)    P(Assoc-acdm|5)    P(Assoc-acdm|10)
# Assoc-voc        P(Assoc-voc|14)     P(Assoc-voc|5)     P(Assoc-voc|10)
# 7th-8th            P(7th-8th|14)       P(7th-8th|5)       P(7th-8th|10)
# Doctorate        P(Doctorate|14)     P(Doctorate|5)     P(Doctorate|10)
# Prof-school    P(Prof-school|14)   P(Prof-school|5)   P(Prof-school|10)
# 5th-6th            P(5th-6th|14)       P(5th-6th|5)       P(5th-6th|10)
# 10th                  P(10th|14)          P(10th|5)          P(10th|10)
# 1st-4th            P(1st-4th|14)       P(1st-4th|5)       P(1st-4th|10)
# Preschool        P(Preschool|14)     P(Preschool|5)     P(Preschool|10)
# 12th                  P(12th|14)          P(12th|5)          P(12th|10)
#
#                               12                  11                 4   \
# Bachelors        P(Bachelors|12)     P(Bachelors|11)     P(Bachelors|4)
# HS-grad            P(HS-grad|12)       P(HS-grad|11)       P(HS-grad|4)
# 11th                  P(11th|12)          P(11th|11)          P(11th|4)
# Masters            P(Masters|12)       P(Masters|11)       P(Masters|4)
# 9th                    P(9th|12)           P(9th|11)           P(9th|4)
# Some-college  P(Some-college|12)  P(Some-college|11)  P(Some-college|4)
# Assoc-acdm      P(Assoc-acdm|12)    P(Assoc-acdm|11)    P(Assoc-acdm|4)
# Assoc-voc        P(Assoc-voc|12)     P(Assoc-voc|11)     P(Assoc-voc|4)
# 7th-8th            P(7th-8th|12)       P(7th-8th|11)       P(7th-8th|4)
# Doctorate        P(Doctorate|12)     P(Doctorate|11)     P(Doctorate|4)
# Prof-school    P(Prof-school|12)   P(Prof-school|11)   P(Prof-school|4)
# 5th-6th            P(5th-6th|12)       P(5th-6th|11)       P(5th-6th|4)
# 10th                  P(10th|12)          P(10th|11)          P(10th|4)
# 1st-4th            P(1st-4th|12)       P(1st-4th|11)       P(1st-4th|4)
# Preschool        P(Preschool|12)     P(Preschool|11)     P(Preschool|4)
# 12th                  P(12th|12)          P(12th|11)          P(12th|4)
#
#                               16                  15                 3   \
# Bachelors        P(Bachelors|16)     P(Bachelors|15)     P(Bachelors|3)
# HS-grad            P(HS-grad|16)       P(HS-grad|15)       P(HS-grad|3)
# 11th                  P(11th|16)          P(11th|15)          P(11th|3)
# Masters            P(Masters|16)       P(Masters|15)       P(Masters|3)
# 9th                    P(9th|16)           P(9th|15)           P(9th|3)
# Some-college  P(Some-college|16)  P(Some-college|15)  P(Some-college|3)
# Assoc-acdm      P(Assoc-acdm|16)    P(Assoc-acdm|15)    P(Assoc-acdm|3)
# Assoc-voc        P(Assoc-voc|16)     P(Assoc-voc|15)     P(Assoc-voc|3)
# 7th-8th            P(7th-8th|16)       P(7th-8th|15)       P(7th-8th|3)
# Doctorate        P(Doctorate|16)     P(Doctorate|15)     P(Doctorate|3)
# Prof-school    P(Prof-school|16)   P(Prof-school|15)   P(Prof-school|3)
# 5th-6th            P(5th-6th|16)       P(5th-6th|15)       P(5th-6th|3)
# 10th                  P(10th|16)          P(10th|15)          P(10th|3)
# 1st-4th            P(1st-4th|16)       P(1st-4th|15)       P(1st-4th|3)
# Preschool        P(Preschool|16)     P(Preschool|15)     P(Preschool|3)
# 12th                  P(12th|16)          P(12th|15)          P(12th|3)
#
#                              6                  2                  1   \
# Bachelors        P(Bachelors|6)     P(Bachelors|2)     P(Bachelors|1)
# HS-grad            P(HS-grad|6)       P(HS-grad|2)       P(HS-grad|1)
# 11th                  P(11th|6)          P(11th|2)          P(11th|1)
# Masters            P(Masters|6)       P(Masters|2)       P(Masters|1)
# 9th                    P(9th|6)           P(9th|2)           P(9th|1)
# Some-college  P(Some-college|6)  P(Some-college|2)  P(Some-college|1)
# Assoc-acdm      P(Assoc-acdm|6)    P(Assoc-acdm|2)    P(Assoc-acdm|1)
# Assoc-voc        P(Assoc-voc|6)     P(Assoc-voc|2)     P(Assoc-voc|1)
# 7th-8th            P(7th-8th|6)       P(7th-8th|2)       P(7th-8th|1)
# Doctorate        P(Doctorate|6)     P(Doctorate|2)     P(Doctorate|1)
# Prof-school    P(Prof-school|6)   P(Prof-school|2)   P(Prof-school|1)
# 5th-6th            P(5th-6th|6)       P(5th-6th|2)       P(5th-6th|1)
# 10th                  P(10th|6)          P(10th|2)          P(10th|1)
# 1st-4th            P(1st-4th|6)       P(1st-4th|2)       P(1st-4th|1)
# Preschool        P(Preschool|6)     P(Preschool|2)     P(Preschool|1)
# 12th                  P(12th|6)          P(12th|2)          P(12th|1)
#
#                              8
# Bachelors        P(Bachelors|8)
# HS-grad            P(HS-grad|8)
# 11th                  P(11th|8)
# Masters            P(Masters|8)
# 9th                    P(9th|8)
# Some-college  P(Some-college|8)
# Assoc-acdm      P(Assoc-acdm|8)
# Assoc-voc        P(Assoc-voc|8)
# 7th-8th            P(7th-8th|8)
# Doctorate        P(Doctorate|8)
# Prof-school    P(Prof-school|8)
# 5th-6th            P(5th-6th|8)
# 10th                  P(10th|8)
# 1st-4th            P(1st-4th|8)
# Preschool        P(Preschool|8)
# 12th                  P(12th|8)

# %%
adults[(adults['education-num'] > 10) & (adults['education-num'] < 16) & (adults['income'] == '>50K') ]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 8       31           Private   45781     Masters             14
# 9       42           Private  159449   Bachelors             13
# 11      30         State-gov  141297   Bachelors             13
# 14      40           Private  121772   Assoc-voc             11
# 19      43  Self-emp-not-inc  292175     Masters             14
# ...    ...               ...     ...         ...            ...
# 32533   54           Private  337992   Bachelors             13
# 32536   34           Private  160216   Bachelors             13
# 32538   38           Private  139180   Bachelors             13
# 32545   39         Local-gov  111499  Assoc-acdm             12
# 32554   53           Private  321865     Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# 9      Married-civ-spouse  Exec-managerial        Husband               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# 14     Married-civ-spouse     Craft-repair        Husband  Asian-Pac-Islander
# 19               Divorced  Exec-managerial      Unmarried               White
# ...                   ...              ...            ...                 ...
# 32533  Married-civ-spouse  Exec-managerial        Husband  Asian-Pac-Islander
# 32536       Never-married  Exec-managerial  Not-in-family               White
# 32538            Divorced   Prof-specialty      Unmarried               Black
# 32545  Married-civ-spouse     Adm-clerical           Wife               White
# 32554  Married-civ-spouse  Exec-managerial        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 8      Female         14084             0              50  United-States
# 9        Male          5178             0              40  United-States
# 11       Male             0             0              40          India
# 14       Male             0             0              40              ?
# 19     Female             0             0              45  United-States
# ...       ...           ...           ...             ...            ...
# 32533    Male             0             0              50          Japan
# 32536  Female             0             0              55  United-States
# 32538  Female         15020             0              45  United-States
# 32545  Female             0             0              20  United-States
# 32554    Male             0             0              40  United-States
#
#       income
# 8       >50K
# 9       >50K
# 11      >50K
# 14      >50K
# 19      >50K
# ...      ...
# 32533   >50K
# 32536   >50K
# 32538   >50K
# 32545   >50K
# 32554   >50K
#
# [4229 rows x 15 columns]
